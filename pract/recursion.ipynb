# %%
def func():
    print("123")

    func()
    func()

    print("456")

# %%
func()
# Out:
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# ...
