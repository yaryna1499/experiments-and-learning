# %%
from pydantic import BaseModel

class User(BaseModel):
    id: int
    name: str
    email: str

class UserCreate(BaseModel):
    name: str | None = None
    email: str
    test: str

class UserUnion1(User, UserCreate):
    pass

class UserUnion2(UserCreate, User):
    pass

UserUnion1.model_fields, UserUnion2.model_fields
# Out:
# ({'name': FieldInfo(annotation=str, required=True),
#   'email': FieldInfo(annotation=str, required=True),
#   'test': FieldInfo(annotation=str, required=True),
#   'id': FieldInfo(annotation=int, required=True)},
#  {'id': FieldInfo(annotation=int, required=True),
#   'name': FieldInfo(annotation=Union[str, NoneType], required=False, default=None),
#   'email': FieldInfo(annotation=str, required=True),
#   'test': FieldInfo(annotation=str, required=True)})
